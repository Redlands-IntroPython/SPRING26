# %%
def mk():
 h=random.randint(5,15)
 return h
    
def br(n,h,e):
    a=input("Do you want to attack? (yes or no)")
    if a.lower()=="yes":
       p=rd()
       g=rd()
       print(n,"rolls:",p)
       print("Goblin rolls:",g)
       if p>g:
          e=e-p
          print("You hit the goblin!")
       elif g>p:
          h=h-g
          print("The goblin hits you!")
       else: print("Tie! No damage.")
       print("Your health:",h)
       print("Goblin health:",e)
       print("-------")
       return h,e
    elif a.lower()=="no":
       return None,None
    else:
       print("Turn skipped for incorrect input!\n")
       return h,e
        
import random
def rd():
 return random.randint(1,6)

print("=== Mini Game ===")
n=input("Enter your name: ")
h=mk()
e=mk()
print("Your starting stats:")
print("Health:",h)
print(f"A wild goblin appears! Their health is {e}\n")
while h>0 and e>0:
 h,e=br(n,h,e)
 if h==None:
  print("You ran away!")
  break
if h!=None:
 if h>0:
  print("You win!")
 else:
  print("You were defeated...")
print("Game over.")
